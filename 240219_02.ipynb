# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt

# %precision 3
# %matplotlib inline

df = pd.read_csv('ch4_scores400.csv')
scores = np.array(df['score'])
scores[:10]
# Out:
# array([76, 55, 80, 80, 74, 61, 81, 76, 23, 80])

# %%
np.random.choice([1,2,3,],3)
# Out:
# array([2, 3, 3])

# %%
np.random.choice([1,2,3],3, replace=False)
# Out:
# array([2, 3, 1])

# %%
np.random.seed(0)
np.random.choice([1,2,3,],3)
# Out:
# array([1, 2, 1])

# %%
np.random.seed(0)
sample = np.random.choice(scores,20)
sample.mean()
# Out:
# 70.400

# %%
scores.mean()
# Out:
# 69.530

# %%
for i in range(5):
    sample = np.random.choice(scores, 20)
    print(f'{i+1}번째 무작위추출로 얻은 표본평균', sample.mean())
# Out:
# 1번째 무작위추출로 얻은 표본평균 70.65
# 2번째 무작위추출로 얻은 표본평균 69.95
# 3번째 무작위추출로 얻은 표본평균 68.8
# 4번째 무작위추출로 얻은 표본평균 69.15
# 5번째 무작위추출로 얻은 표본평균 71.25

# %%
dice = [1,2,3,4,5,6]
prob = [1/21, 2/21, 3/21, 4/21, 5/21, 6/21]

# %%
np.random.choice(dice, p=prob)
# Out:
# 6

# %%
num_trial = 100
sample = np.random.choice(dice, num_trial, p=prob)
sample
# Out:
# array([5, 6, 3, 5, 2, 5, 6, 6, 4, 6, 3, 6, 6, 6, 5, 6, 4, 6, 5, 1, 4, 3,
#        6, 5, 5, 5, 4, 2, 6, 3, 5, 3, 2, 6, 6, 6, 6, 6, 4, 2, 4, 3, 2, 2,
#        6, 1, 6, 3, 2, 2, 5, 3, 4, 5, 6, 6, 3, 2, 2, 4, 3, 4, 5, 5, 3, 4,
#        3, 6, 2, 5, 6, 6, 3, 4, 5, 3, 4, 3, 4, 1, 6, 2, 5, 4, 5, 6, 5, 1,
#        4, 5, 5, 5, 3, 2, 4, 6, 3, 6, 5, 4])

# %%
freq, _ = np.histogram(sample, bins=6, range=(1,7))
pd.DataFrame({'frequency': freq, 'relative frequency': freq/num_trial}, index=pd.Index(np.arange(1,7), name = 'dice'))
# Out:
#       frequency  relative frequency
# dice
# 1             4                0.04
# 2            13                0.13
# 3            17                0.17
# 4            17                0.17
# 5            22                0.22
# 6            27                0.27

# %%
fig = plt.figure(figsize=(10,6))
ax = fig.add_subplot(111)
ax.hist(sample, bins=6, range=(1,7), density=True, rwidth=0.8)
ax.hlines(prob, np.arange(1,7), np.arange(2,8), colors = 'gray')
ax.set_xticks(np.linspace(1.5,6.5,6))
ax.set_xticklabels(np.arrange(1,7))
ax.set_xlabel('dice')
ax.set_ylabel('relative frequency')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[22], line 6
#       4 ax.hlines(prob, np.arange(1,7), np.arange(2,8), colors = 'gray')
#       5 ax.set_xticks(np.linspace(1.5,6.5,6))
# ----> 6 ax.set_xticklabels(np.arrange(1,7))
#       7 ax.set_xlabel('dice')
#       8 ax.set_ylabel('relative frequency')
#
# File ~/anaconda3/envs/My_38/lib/python3.8/site-packages/numpy/__init__.py:320, in __getattr__(attr)
#     317     from .testing import Tester
#     318     return Tester
# --> 320 raise AttributeError("module {!r} has no attribute "
#     321                      "{!r}".format(__name__, attr))
#
# AttributeError: module 'numpy' has no attribute 'arrange'

# %%
num_trial = 10000
sample = np.random.choice(dice, size=num_trial, p=prob)

fig = plt.figure(figsize=(10,6))
ax = fig.add_subplot(111)
ax.hist(sample, bins=6, range=(1,7), density=True, rwidth=0.8)
ax.hlines(prob, np.arange(1,7), np.arange(2,8), colors = 'gray')
ax.set_xticks(np.linspace(1.5,6.5,6))
ax.set_xticklabels(np.arrange(1,7))
ax.set_xlabel('dice')
ax.set_ylabel('relative frequency')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[24], line 9
#       7 ax.hlines(prob, np.arange(1,7), np.arange(2,8), colors = 'gray')
#       8 ax.set_xticks(np.linspace(1.5,6.5,6))
# ----> 9 ax.set_xticklabels(np.arrange(1,7))
#      10 ax.set_xlabel('dice')
#      11 ax.set_ylabel('relative frequency')
#
# File ~/anaconda3/envs/My_38/lib/python3.8/site-packages/numpy/__init__.py:320, in __getattr__(attr)
#     317     from .testing import Tester
#     318     return Tester
# --> 320 raise AttributeError("module {!r} has no attribute "
#     321                      "{!r}".format(__name__, attr))
#
# AttributeError: module 'numpy' has no attribute 'arrange'

# %%
fig = plt.figure(figsize=(10,6))
ax = fig.add_subplot(111)
ax.hist(scores, bins=100, range=(0,100), density=True)
ax.set_xlim(20,100)
ax.set_ylim(0,0.042)
ax.set_xlabel('score')
ax.set_ylabel('relative frequency')
plt.show()

# %%
np.random.choice(scores)
# Out:
# 72

# %%
sample = np.random.choice(scores, 10000)

fig = plt.figure(figsize=(10,6))
ax = fig.add_subplot(111)
ax.hist(sample, bins=100, range=(0,100), density=True)
ax.set_xlim(20,100)
ax.set_ylim(0,0.042)
ax.set_xlabel('score')
ax.set_ylabel('relative frequency')
plt.show()

# %%
sample_means = [np.random.choice(scores, 20).mean()
                for _ in range(10000)]


fig = plt.figure(figsize=(10,6))
ax = fig.add_subplot(111)
ax.hist(sample_means, bins=100, range=(0,100), density=True)
ax.vlines(np.mean(scores), 0, 1, 'gray') # 세로 선 - 위치, 최소값0, 최대값1, 색상
ax.set_xlim(50, 90)
ax.set_ylim(0,0.13)
ax.set_xlabel('score')
ax.set_ylabel('relative frequency')
plt.show()
